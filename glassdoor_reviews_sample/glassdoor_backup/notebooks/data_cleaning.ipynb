# %%
import pandas as pd

# Load your raw file (adjust filename if needed)
df = pd.read_csv('../data/glassdoor_sample_former_employees_100k.csv')

# Peek
df.head()
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   rating                     100000 non-null  float64
#  1   title                      99686 non-null   object
#  2   status                     100000 non-null  object
#  3   pros                       100000 non-null  object
#  4   cons                       100000 non-null  object
#  5   advice                     0 non-null       float64
#  6   Recommend                  100000 non-null  object
#  7   CEO Approval               100000 non-null  object
#  8   Business Outlook           100000 non-null  object
#  9   Career Opportunities       79200 non-null   object
#  10  Compensation and Benefits  78835 non-null   object
#  11  Senior Management          77639 non-null   object
#  12  Work/Life Balance          78643 non-null   object
#  13  Culture & Values           75697 non-null   float64
#  14  Diversity & Inclusion      31660 non-null   float64
#  15  firm_link                  100000 non-null  object
#  16  date                       100000 non-null  object
#  17  job                        100000 non-null  object
#  18  index                      0 non-null       float64
# dtypes: float64(5), object(14)
# memory usage: 14.5+ MB
#                rating  title           status                       pros  \
# count   100000.000000  99686           100000                     100000
# unique            NaN  56152                7                      96363
# top               NaN   Good  Former Employee  Great people to work with
# freq              NaN   1443            39629                         69
# mean         3.226060    NaN              NaN                        NaN
# std          1.300659    NaN              NaN                        NaN
# min          1.000000    NaN              NaN                        NaN
# 25%          2.000000    NaN              NaN                        NaN
# 50%          3.000000    NaN              NaN                        NaN
# 75%          4.000000    NaN              NaN                        NaN
# max          5.000000    NaN              NaN                        NaN
#
#                             cons  advice Recommend CEO Approval  \
# count                     100000     0.0    100000       100000
# unique                     96702     NaN         3            4
# top     None that I can think of     NaN         v            o
# freq                         124     NaN     35634        40890
# mean                         NaN     NaN       NaN          NaN
# std                          NaN     NaN       NaN          NaN
# min                          NaN     NaN       NaN          NaN
# 25%                          NaN     NaN       NaN          NaN
# 50%                          NaN     NaN       NaN          NaN
# 75%                          NaN     NaN       NaN          NaN
# max                          NaN     NaN       NaN          NaN
#
#        Business Outlook Career Opportunities Compensation and Benefits  \
# count            100000                79200                     78835
# unique                4                   14                        14
# top                   o                    3                         3
# freq              38622                18108                     18735
# mean                NaN                  NaN                       NaN
# std                 NaN                  NaN                       NaN
# min                 NaN                  NaN                       NaN
# 25%                 NaN                  NaN                       NaN
# 50%                 NaN                  NaN                       NaN
# 75%                 NaN                  NaN                       NaN
# max                 NaN                  NaN                       NaN
#
#        Senior Management Work/Life Balance  Culture & Values  \
# count              77639             78643      75697.000000
# unique                14                14               NaN
# top                    1                 3               NaN
# freq               18386             17700               NaN
# mean                 NaN               NaN          3.111312
# std                  NaN               NaN          1.449040
# min                  NaN               NaN          1.000000
# 25%                  NaN               NaN          2.000000
# 50%                  NaN               NaN          3.000000
# 75%                  NaN               NaN          4.000000
# max                  NaN               NaN          5.000000
#
#         Diversity & Inclusion                              firm_link  \
# count            31660.000000                                 100000
# unique                    NaN                                    728
# top                       NaN  Reviews/Chipotle-Reviews-E1370610.htm
# freq                      NaN                                   9038
# mean                 3.553411                                    NaN
# std                  1.388412                                    NaN
# min                  1.000000                                    NaN
# 25%                  3.000000                                    NaN
# 50%                  4.000000                                    NaN
# 75%                  5.000000                                    NaN
# max                  5.000000                                    NaN
#
#                  date                  job  index
# count          100000               100000    0.0
# unique           5119                12883    NaN
# top     Jan 14, 2021    Anonymous Employee    NaN
# freq              133                17795    NaN
# mean              NaN                  NaN    NaN
# std               NaN                  NaN    NaN
# min               NaN                  NaN    NaN
# 25%               NaN                  NaN    NaN
# 50%               NaN                  NaN    NaN
# 75%               NaN                  NaN    NaN
# max               NaN                  NaN    NaN
